# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '2011 Stack Overflow Survey Results.csv',
#  '2024 Developer Survey.pdf',
#  'citisalary.csv',
#  'clevelanda (2).csv',
#  'Data Visualization with Seaborn-3.ipynb',
#  'dec_2022.png',
#  'Dec_Anal.png',
#  'Electric_Vehicle_Population_Data.csv',
#  'ETH_1h.csv',
#  'first.ipynb',
#  'first2.ipynb',
#  'first3.ipynb',
#  'first7.ipynb',
#  'inherintance and cls method .ipynb',
#  'iris.csv',
#  'leading data 1.xlsx',
#  'LinkedList.ipynb',
#  'Marketing_conversion_data.xlsx',
#  'mod.json',
#  'mod.xlsx',
#  'mod3.json',
#  'modi.tsv',
#  'modifided.csv',
#  'new.py',
#  'newfirst.ipynb',
#  'panda and sea,polt and mat.ipynb',
#  'plotly-4.ipynb',
#  'Sales Data.xlsx',
#  'sorting.ipynb',
#  'stack and queue.ipynb',
#  'static in python.ipynb',
#  'survey_results_public.csv',
#  'survey_results_schema.csv',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled10.ipynb',
#  'Untitled11.ipynb',
#  'Untitled12.ipynb',
#  'Untitled13.ipynb',
# ...

# %%
data=pd.read_csv('Electric_Vehicle_Population_Data.csv')
data
# Out:
#         VIN (1-10)     County           City State  Postal Code  Model Year  \
# 0       5YJYGDEE1L       King        Seattle    WA      98122.0        2020
# 1       7SAYGDEE9P  Snohomish        Bothell    WA      98021.0        2023
# 2       5YJSA1E4XK       King        Seattle    WA      98109.0        2019
# 3       5YJSA1E27G       King       Issaquah    WA      98027.0        2016
# 4       5YJYGDEE5M     Kitsap      Suquamish    WA      98392.0        2021
# ...            ...        ...            ...   ...          ...         ...
# 177861  7SAYGDEE3N     Pierce    Bonney Lake    WA      98391.0        2022
# 177862  KM8K23AG1P      Mason        Shelton    WA      98584.0        2023
# 177863  5YJYGDEE6M      Grant         Quincy    WA      98848.0        2021
# 177864  WVGKMPE27M       King  Black Diamond    WA      98010.0        2021
# 177865  5YJ3E1EA8M     Pierce         Tacoma    WA      98422.0        2021
#
# ...

# %%
data.columns
# Out:
# Index(['VIN (1-10)', 'County', 'City', 'State', 'Postal Code', 'Model Year',
#        'Make', 'Model', 'Electric Vehicle Type',
#        'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Range',
#        'Base MSRP', 'Legislative District', 'DOL Vehicle ID',
#        'Vehicle Location', 'Electric Utility', '2020 Census Tract'],
#       dtype='object')

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(12,6))
k=data['Model Year'].value_counts().sort_index()
sns.barplot(x=k.index,y=k.values,palette="viridis")
plt.title('EV Adoption Over Time')
plt.xlabel('Model year')
plt.ylabel('Number of Vehicles Registered')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_1580\3480315048.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=k.index,y=k.values,palette="viridis")

# %%
ev_count=data['County'].value_counts()
top_country=ev_count.head(3).index
top_con=data[data['County'].isin(top_country)]
ev_city_distribution_top_counties = top_con.groupby(['County', 'City']).size().sort_values(ascending=False).reset_index(name='Number of Vehicles')
top_citis=ev_city_distribution_top_counties.head(10)

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(12,6))
sns.barplot(x='Number of Vehicles', y='City', hue='County', data=top_citis, palette="magma")
plt.xlabel('Number of Vehicles Registered')
plt.ylabel('City')
plt.legend(title='County')
plt.tight_layout()
plt.show()

# %%
vehi_type=data['Electric Vehicle Type'].value_counts()
vehi_type
# Out:
# Electric Vehicle Type
# Battery Electric Vehicle (BEV)            139210
# Plug-in Hybrid Electric Vehicle (PHEV)     38656
# Name: count, dtype: int64

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(12,6))
sns.barplot(x=vehi_type.values,y=vehi_type.index,palette="viridis")
plt.title('Distribution of Electric Vehicle Types')
plt.xlabel('Number of Vehicles Registered')
plt.ylabel('Electric Vehicle Type')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3324\1405643696.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=vehi_type.values,y=vehi_type.index,palette="viridis")

# %%
ev_make_distribution = data['Make'].value_counts().head(10)
ev_make_distribution
# Out:
# Make
# TESLA         79659
# NISSAN        13998
# CHEVROLET     13678
# FORD           9199
# BMW            7570
# KIA            7432
# TOYOTA         6288
# VOLKSWAGEN     5004
# JEEP           4480
# HYUNDAI        4406
# Name: count, dtype: int64

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(12,6))
sns.barplot(x=ev_make_distribution.values,y=ev_make_distribution.index,palette="viridis")
plt.title('Distribution of Electric Vehicle Types')
plt.xlabel('Number of Vehicles Registered')
plt.ylabel('Electric Vehicle Type')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_1580\2860783814.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=ev_make_distribution.values,y=ev_make_distribution.index,palette="viridis")

# %%
top_3_makes = ev_make_distribution.head(3).index

# %%
top_makes_data = data[data['Make'].isin(top_3_makes)]
top_makes_data
ev_model_distribution_top_makes = top_makes_data.groupby(['Make', 'Model']).size().sort_values(ascending=False).reset_index(name='Number of Vehicles')
top_models = ev_model_distribution_top_makes.head(10)

# %%
plt.figure(figsize=(12,8))
sns.barplot(x='Number of Vehicles',y='Model',hue='Make',data=top_models,palette="viridis")
plt.title('Top Models In Top 3 Makes by EV Registrations')
plt.ylabel('Model')
plt.legend(title='Make', loc='center right')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.histplot(data['Electric Range'], bins=30, kde=True, color='royalblue')
plt.title('Distribution of Electric Vehicle Ranges')
plt.xlabel('Electric Range (miles)')
plt.ylabel('Number of Vehicles')
plt.axvline(data['Electric Range'].mean(), color='red', linestyle='--', label=f'Mean Range: {data["Electric Range"].mean():.2f} miles')
plt.legend()
plt.show()

# %%
average_range_by_year = data.groupby('Model Year')['Electric Range'].mean().reset_index()
average_range_by_year
# Out:
#     Model Year  Electric Range
# 0         1997       39.000000
# 1         1998       58.000000
# 2         1999       74.000000
# 3         2000       58.000000
# 4         2002       95.000000
# 5         2003       95.000000
# 6         2008      220.000000
# 7         2010      226.086957
# 8         2011       70.891613
# 9         2012       61.212608
# 10        2013       79.852574
# 11        2014       80.669706
# 12        2015       98.164740
# 13        2016      101.279227
# 14        2017      114.124153
# 15        2018      156.140194
# 16        2019      176.892596
# 17        2020      238.690347
# 18        2021       11.408426
# 19        2022        4.523870
# 20        2023        3.731207
# 21        2024       16.791667

# %%
plt.figure(figsize=(12,6))
sns.lineplot(x='Model Year',y='Electric Range',data=average_range_by_year,marker='o',color='green')
plt.title('Electric Range by Model year')
plt.xlabel('Model Year')
plt.ylabel('Average Electric Range (miles)')
plt.grid(True)
plt.show()

# %%
average_range_by_model = top_makes_data.groupby(['Make', 'Model'])['Electric Range'].mean().sort_values(ascending=False).reset_index()
top_range_models = average_range_by_model.head(10)
plt.figure(figsize=(12, 6))
sns.barplot(x='Electric Range', y='Model', hue='Make', data=top_range_models, palette="cool")
plt.title('Top 10 Models by Average Electric Range in Top Makes')
plt.xlabel('Average Electric Range (miles)')
plt.ylabel('Model')
plt.legend(title='Make', loc='center right')
plt.show()

# %%
ev_registration_counts = data['Model Year'].value_counts().sort_index()
ev_registration_counts
# Out:
# Model Year
# 1997        1
# 1998        1
# 1999        5
# 2000        7
# 2002        2
# 2003        1
# 2008       20
# 2010       23
# 2011      775
# 2012     1618
# 2013     4409
# 2014     3509
# 2015     4844
# 2016     5483
# 2017     8562
# 2018    14323
# 2019    10940
# 2020    11768
# 2021    19132
# 2022    27776
# 2023    57587
# 2024     7080
# Name: count, dtype: int64

# %%
from scipy.optimize import curve_fit
import numpy as np


filtered_years = ev_registration_counts[ev_registration_counts.index <= 2023]


def exp_growth(x, a, b):
    return a * np.exp(b * x)


x_data = filtered_years.index - filtered_years.index.min()
y_data = filtered_years.values


params, covariance = curve_fit(exp_growth, x_data, y_data)


forecast_years = np.arange(2024, 2024 + 6) - filtered_years.index.min()
forecasted_values = exp_growth(forecast_years, *params)

forecasted_evs = dict(zip(forecast_years + filtered_years.index.min(), forecasted_values))

print(forecasted_evs)
# Out:
# {np.int64(2024): np.float64(79092.26358070358), np.int64(2025): np.float64(119565.00850312428), np.int64(2026): np.float64(180748.2882793602), np.int64(2027): np.float64(273240.0066284026), np.int64(2028): np.float64(413061.179903938), np.int64(2029): np.float64(624431.02841697)}

# %%
years = np.arange(filtered_years.index.min(), 2029 + 1)
actual_years = filtered_years.index
forecast_years_full = np.arange(2024, 2029 + 1)
actual_values = filtered_years.values
forecasted_values_full = [forecasted_evs[year] for year in forecast_years_full]


plt.figure(figsize=(12, 8))
plt.plot(actual_years, actual_values, 'bo-', label='Actual Registrations')
plt.plot(forecast_years_full, forecasted_values_full, 'ro--', label='Forecasted Registrations')
